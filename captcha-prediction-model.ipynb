# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        # print(os.path.join(dirname, filename))
        pass

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import matplotlib.pyplot as plt
from PIL import Image
from sklearn.model_selection import train_test_split
import tensorflow as tf

img=Image.open('/kaggle/input/captcha-version-2-images/samples/samples/37d52.png')
plt.imshow(img)
plt.show()
# Out:
# 2025-04-26 04:49:46.150263: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1745642986.428387      31 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1745642986.508368      31 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
image_dir='/kaggle/input/captcha-version-2-images/samples/samples/'
IMG_WIDTH, IMG_HEIGHT=100,50

# %%
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.utils import to_categorical

all_characters='0123456789abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ'

label_encoder=LabelEncoder()
label_encoder.fit(list(all_characters))

def encoder_label(label):
    return label_encoder.transform(list(label))

encoded_label = encoder_label('6n6gg')
print("Encoded label:", encoded_label)
# Out:
# Encoded label: [ 6 49  6 42 42]

# %%
def one_hot_encode_label(encoded_label):
    return to_categorical(encoded_label, num_classes=len(all_characters))

# %%
images = []
labels = []

for filename in os.listdir(image_dir):
    if filename.endswith('.png'):
        img_path = os.path.join(image_dir, filename)
        img = Image.open(img_path).convert("L")
        img = img.resize((IMG_WIDTH, IMG_HEIGHT), resample=Image.Resampling.LANCZOS)
        img_array = np.array(img) / 255.0
        images.append(img_array)

        label=os.path.splitext(filename)[0]
        encoded_label=encoder_label(label)
        one_hot_label=one_hot_encode_label(encoded_label)
        

        labels.append(one_hot_label)

# %%
images=np.array(images)
labels=np.array(labels)

# %%
images=images.reshape(-1,IMG_HEIGHT,IMG_WIDTH, 1)
images.shape
# Out:
# (1040, 50, 100, 1)

# %%
X_train,X_test,y_train,y_test=train_test_split(images,labels,test_size=0.2, random_state=42)
print(X_train[0].shape)
# Out:
# (50, 100, 1)

# %%
from tensorflow import keras
from keras import Sequential
from keras.layers import Dense,Conv2D,MaxPooling2D,Flatten,Reshape,TimeDistributed,Dropout,BatchNormalization

# %%
NUM_CHARACTERS = 5
NUM_CLASSES = 62  # 0-9, a-z, A-Z

model = Sequential()
model.add(Conv2D(64, kernel_size=(3,3), padding='valid', activation='relu', input_shape=(50,100,1)))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2), strides=2, padding='valid'))
model.add(Dropout(0.2))

model.add(Conv2D(32, kernel_size=(3,3), padding='valid', activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2), strides=2, padding='valid'))
model.add(Dropout(0.2))

model.add(Flatten())
model.add(Dense(NUM_CHARACTERS * NUM_CLASSES, activation='relu'))  # Expand output
model.add(Dropout(0.2))

# Reshape to (5, 62) for TimeDistributed softmax
model.add(Reshape((NUM_CHARACTERS, NUM_CLASSES)))
model.add(TimeDistributed(Dense(NUM_CLASSES, activation='softmax')))

# %%
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
history=model.fit(X_train,y_train, epochs=60, validation_data=(X_test,y_test))
# Out:
# Epoch 1/60
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 12s 336ms/step - accuracy: 0.0473 - loss: 4.0804 - val_accuracy: 0.0625 - val_loss: 4.0972
# Epoch 2/60
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 9s 333ms/step - accuracy: 0.1305 - loss: 3.0983 - val_accuracy: 0.1096 - val_loss: 4.0693
# Epoch 3/60
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 8s 327ms/step - accuracy: 0.2670 - loss: 2.3969 - val_accuracy: 0.2894 - val_loss: 3.9804
# Epoch 4/60
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 9s 330ms/step - accuracy: 0.4193 - loss: 1.8570 - val_accuracy: 0.4567 - val_loss: 3.8291
# Epoch 5/60
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 9s 359ms/step - accuracy: 0.5577 - loss: 1.4025 - val_accuracy: 0.5856 - val_loss: 3.5965
# Epoch 6/60
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 9s 324ms/step - accuracy: 0.6173 - loss: 1.1613 - val_accuracy: 0.6712 - val_loss: 3.4105
# Epoch 7/60
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 8s 325ms/step - accuracy: 0.6878 - loss: 0.9102 - val_accuracy: 0.7298 - val_loss: 3.1550
# Epoch 8/60
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 8s 316ms/step - accuracy: 0.7079 - loss: 0.8183 - val_accuracy: 0.7654 - val_loss: 2.9179
# Epoch 9/60
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 9s 345ms/step - accuracy: 0.7486 - loss: 0.6983 - val_accuracy: 0.7712 - val_loss: 2.5836
# Epoch 10/60
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 8s 320ms/step - accuracy: 0.7788 - loss: 0.6359 - val_accuracy: 0.8154 - val_loss: 2.3361
# Epoch 11/60
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 10s 322ms/step - accuracy: 0.8051 - loss: 0.5725 - val_accuracy: 0.8385 - val_loss: 2.0581
# Epoch 12/60
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 8s 323ms/step - accuracy: 0.8101 - loss: 0.5299 - val_accuracy: 0.8240 - val_loss: 1.8744
# Epoch 13/60
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 11s 343ms/step - accuracy: 0.8258 - loss: 0.4896 - val_accuracy: 0.8346 - val_loss: 1.4788
# Epoch 14/60
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 8s 319ms/step - accuracy: 0.8349 - loss: 0.4622 - val_accuracy: 0.8183 - val_loss: 1.3899
# Epoch 15/60
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 9s 327ms/step - accuracy: 0.8488 - loss: 0.4373 - val_accuracy: 0.8308 - val_loss: 1.1957
# Epoch 16/60
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 9s 347ms/step - accuracy: 0.8439 - loss: 0.4320 - val_accuracy: 0.8327 - val_loss: 1.0057
# Epoch 17/60
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 8s 316ms/step - accuracy: 0.8632 - loss: 0.4050 - val_accuracy: 0.8365 - val_loss: 0.8680
# Epoch 18/60
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 10s 317ms/step - accuracy: 0.8609 - loss: 0.3968 - val_accuracy: 0.8423 - val_loss: 0.7599
# Epoch 19/60
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 10s 316ms/step - accuracy: 0.8463 - loss: 0.4149 - val_accuracy: 0.8538 - val_loss: 0.6672
# Epoch 20/60
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 11s 340ms/step - accuracy: 0.8637 - loss: 0.3882 - val_accuracy: 0.8317 - val_loss: 0.6609
# Epoch 21/60
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 9s 328ms/step - accuracy: 0.8587 - loss: 0.3749 - val_accuracy: 0.8510 - val_loss: 0.6021
# Epoch 22/60
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 10s 320ms/step - accuracy: 0.8504 - loss: 0.3953 - val_accuracy: 0.8433 - val_loss: 0.5988
# Epoch 23/60
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 9s 338ms/step - accuracy: 0.8729 - loss: 0.3622 - val_accuracy: 0.8452 - val_loss: 0.6057
# Epoch 24/60
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 8s 322ms/step - accuracy: 0.8706 - loss: 0.3616 - val_accuracy: 0.8702 - val_loss: 0.5627
# Epoch 25/60
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 8s 320ms/step - accuracy: 0.8857 - loss: 0.3272 - val_accuracy: 0.8606 - val_loss: 0.5465
# Epoch 26/60
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 8s 323ms/step - accuracy: 0.8877 - loss: 0.3238 - val_accuracy: 0.8721 - val_loss: 0.5482
# Epoch 27/60
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 9s 340ms/step - accuracy: 0.8724 - loss: 0.3461 - val_accuracy: 0.8750 - val_loss: 0.5455
# Epoch 28/60
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 8s 321ms/step - accuracy: 0.8821 - loss: 0.3190 - val_accuracy: 0.8596 - val_loss: 0.5551
# Epoch 29/60
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 10s 322ms/step - accuracy: 0.8970 - loss: 0.2977 - val_accuracy: 0.8692 - val_loss: 0.5785
# Epoch 30/60
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 8s 316ms/step - accuracy: 0.8868 - loss: 0.3110 - val_accuracy: 0.8663 - val_loss: 0.5970
# Epoch 31/60
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 9s 342ms/step - accuracy: 0.8976 - loss: 0.2954 - val_accuracy: 0.8625 - val_loss: 0.5911
# Epoch 32/60
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 8s 317ms/step - accuracy: 0.9030 - loss: 0.2726 - val_accuracy: 0.8779 - val_loss: 0.5629
# Epoch 33/60
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 8s 317ms/step - accuracy: 0.8942 - loss: 0.2894 - val_accuracy: 0.8673 - val_loss: 0.6303
# Epoch 34/60
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 11s 338ms/step - accuracy: 0.8943 - loss: 0.2803 - val_accuracy: 0.8750 - val_loss: 0.6078
# Epoch 35/60
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 8s 319ms/step - accuracy: 0.8973 - loss: 0.2792 - val_accuracy: 0.8750 - val_loss: 0.5675
# Epoch 36/60
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 10s 329ms/step - accuracy: 0.8987 - loss: 0.2665 - val_accuracy: 0.8788 - val_loss: 0.5557
# Epoch 37/60
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 8s 319ms/step - accuracy: 0.8977 - loss: 0.2842 - val_accuracy: 0.8808 - val_loss: 0.5681
# Epoch 38/60
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 9s 354ms/step - accuracy: 0.8949 - loss: 0.2765 - val_accuracy: 0.8663 - val_loss: 0.6117
# Epoch 39/60
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 9s 334ms/step - accuracy: 0.9140 - loss: 0.2498 - val_accuracy: 0.8808 - val_loss: 0.5718
# Epoch 40/60
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 9s 342ms/step - accuracy: 0.8991 - loss: 0.2713 - val_accuracy: 0.8683 - val_loss: 0.6351
# Epoch 41/60
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 11s 369ms/step - accuracy: 0.9087 - loss: 0.2510 - val_accuracy: 0.8683 - val_loss: 0.6019
# Epoch 42/60
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 9s 361ms/step - accuracy: 0.9149 - loss: 0.2312 - val_accuracy: 0.8740 - val_loss: 0.6432
# Epoch 43/60
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 10s 356ms/step - accuracy: 0.9079 - loss: 0.2480 - val_accuracy: 0.8692 - val_loss: 0.6507
# Epoch 44/60
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 11s 369ms/step - accuracy: 0.9102 - loss: 0.2366 - val_accuracy: 0.8721 - val_loss: 0.7198
# Epoch 45/60
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 9s 346ms/step - accuracy: 0.9097 - loss: 0.2474 - val_accuracy: 0.8798 - val_loss: 0.6102
# Epoch 46/60
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 9s 337ms/step - accuracy: 0.9106 - loss: 0.2403 - val_accuracy: 0.8654 - val_loss: 0.7246
# Epoch 47/60
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 9s 347ms/step - accuracy: 0.8964 - loss: 0.2939 - val_accuracy: 0.8817 - val_loss: 0.6166
# Epoch 48/60
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 10s 366ms/step - accuracy: 0.9067 - loss: 0.2427 - val_accuracy: 0.8808 - val_loss: 0.6269
# Epoch 49/60
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 9s 341ms/step - accuracy: 0.9056 - loss: 0.2532 - val_accuracy: 0.8837 - val_loss: 0.6086
# Epoch 50/60
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 9s 336ms/step - accuracy: 0.9005 - loss: 0.2700 - val_accuracy: 0.8827 - val_loss: 0.6029
# Epoch 51/60
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 9s 346ms/step - accuracy: 0.9134 - loss: 0.2208 - val_accuracy: 0.8817 - val_loss: 0.6133
# Epoch 52/60
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 9s 364ms/step - accuracy: 0.9196 - loss: 0.2247 - val_accuracy: 0.8683 - val_loss: 0.7229
# Epoch 53/60
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 9s 348ms/step - accuracy: 0.9148 - loss: 0.2257 - val_accuracy: 0.8788 - val_loss: 0.5534
# Epoch 54/60
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 9s 365ms/step - accuracy: 0.9205 - loss: 0.2164 - val_accuracy: 0.8856 - val_loss: 0.5572
# Epoch 55/60
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 9s 362ms/step - accuracy: 0.9140 - loss: 0.2254 - val_accuracy: 0.8788 - val_loss: 0.6220
# Epoch 56/60
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 9s 346ms/step - accuracy: 0.9026 - loss: 0.2705 - val_accuracy: 0.8779 - val_loss: 0.6239
# Epoch 57/60
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 10s 341ms/step - accuracy: 0.9121 - loss: 0.2311 - val_accuracy: 0.8779 - val_loss: 0.6175
# Epoch 58/60
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 10s 338ms/step - accuracy: 0.9151 - loss: 0.2208 - val_accuracy: 0.8779 - val_loss: 0.6601
# Epoch 59/60
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 9s 353ms/step - accuracy: 0.9234 - loss: 0.2004 - val_accuracy: 0.8779 - val_loss: 0.6680
# Epoch 60/60
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 9s 329ms/step - accuracy: 0.9183 - loss: 0.2048 - val_accuracy: 0.8817 - val_loss: 0.6509

# %%
plt.plot(history.history['loss'], label='training error', color='red')
plt.plot(history.history['val_loss'], label='validation error', color='blue')
plt.legend()
plt.show()

# %%
plt.imshow(X_test[0])
X_test[0].shape
# Out:
# (50, 100, 1)

# %%
y_pred = model.predict(X_test[0].reshape(1, 50, 100, 1))  # Shape: (1, 5, 62)
y_pred = np.argmax(y_pred, axis=2)  # Now shape is (1, 5)
print(y_pred[0])  # Output: array of 5 predicted class indices
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# [ 4  4 38  2  2]

# %%
characters = list("0123456789abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ")
predicted_text=''.join([characters[i] for i in y_pred[0]])
predicted_text
# Out:
# '44C22'
